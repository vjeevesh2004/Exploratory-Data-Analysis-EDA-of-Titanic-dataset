# %% [markdown]
# <a href="https://colab.research.google.com/github/vjeevesh2004/Exploratory-Data-Analysis-EDA-of-Titanic-dataset/blob/main/Exploratory_Data_Analysis(EDA)_of_Titanic_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
